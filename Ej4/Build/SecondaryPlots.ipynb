# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("secondary.csv")
# Conteo por tipo de partícula
print(df["name"].value_counts())
# Out:
# name
# e-       38504
# gamma    13180
# e+           6
# O16          6
# Name: count, dtype: int64

# %%
print(df.columns)
# Out:
# Index(['name', 'ekin_MeV', 'posX_mm', 'posY_mm', 'posZ_mm', 'momX', 'momY',
#        'momZ', 'process'],
#       dtype='object')

# %%
# Histograma de energías
df[df["name"]=="e-"]["ekin_MeV"].hist(bins=50)
plt.xlabel("Energy [MeV]")
plt.ylabel("Counts")
plt.title("Electron energy spectrum")
plt.show()
mom = df[["momX","momY","momZ"]].to_numpy()
cos_theta = mom[:,2] / np.linalg.norm(mom, axis=1)
plt.hist(cos_theta, bins=50)
plt.xlabel("cos(theta)")
plt.ylabel("Counts")
plt.title("Angular distribution")
plt.show()
